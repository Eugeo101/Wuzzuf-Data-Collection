# %% [markdown]
# # Project

# %%
import requests
from bs4 import BeautifulSoup
# title	link	location	job_type	years	skills	company name

link = "https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=0"
# https://diwanegypt.com/product-category/books/english-books/

res = requests.get(link)
res
# Out:
# <Response [200]>

# %%
# job_title, company_name, company_location, post_time, job_type, work_location, experince_years, level, job_skills, url
soup = BeautifulSoup(res.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" translate="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires">
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <meta content="notranslate" name="googlebot"/>
# <title data-react-helmet="true">Job Search | WUZZUF</title>
# ...

# %%
# job_title, company_name, company_location, post_time, job_type, work_location, experince_years, level, job_skills, url

job_tags = soup.find_all("div", attrs={"class":"css-1gatmva e1v1l3u10"})
job_tags
# Out:
# [<div class="css-1gatmva e1v1l3u10"><style data-emotion="css pkv5jc">.css-pkv5jc{position:relative;min-height:60px;}</style><div class="css-pkv5jc"><a href="https://wuzzuf.net/jobs/careers/Care-Dental-Egypt-27404" rel="noreferrer" target="_blank"><style data-emotion="css 17095x3">.css-17095x3{position:absolute;right:0;top:0;width:60px;height:60px;object-fit:contain;object-position:center center;}</style></a><style data-emotion="css laomuu">.css-laomuu{padding-right:60px;}</style><div class="css-laomuu"><style data-emotion="css m604qf">.css-m604qf{font-size:16px;font-weight:600;font-style:normal;letter-spacing:-0.4px;line-height:24px;color:#0055D9;margin:0;}</style><h2 class="css-m604qf"><style data-emotion="css o171kl">.css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}</style><a class="css-o171kl" href="https://wuzzuf.net/internship/1kma8fGoLuav-AI-Data-Science-Python-Developer-Intern-Sequel-Solutions-Cairo-Egypt" rel="noreferrer" target="_blank">AI &amp; D
# ...

# %%
len(job_tags)
# Out:
# 15

# %%
# title, url
job_title_tag = job_tags[0].find("a", attrs={'class':"css-o171kl"})
job_title = job_title_tag.text
url = job_title_tag.attrs['href']
job_title
# Out:
# 'AI & Data Science Python Developer Intern'

# %%
url
# Out:
# 'https://wuzzuf.net/internship/1kma8fGoLuav-AI-Data-Science-Python-Developer-Intern-Sequel-Solutions-Cairo-Egypt'

# %%
# company name
company_name = job_tags[0].find("a", attrs={"class":"css-17s97q8"}).text.strip(" -")
company_name
# Out:
# 'Sequel Solutions'

# %%
# location
company_location = job_tags[0].find("span", attrs={"class":"css-5wys0k"}).text.strip()
company_location
# Out:
# 'Cairo, Egypt'

# %%
# time
time = job_tags[0].find("div", attrs={"class":"css-d7j1kk"}).find("div").text # brown and green styles
time
# Out:
# '1 month ago'

# %%
# job_type, work_location
job_type_tag = job_tags[0].find("div", attrs={"class":"css-1lh32fc"}).find_all("a")
len(job_type_tag)
# Out:
# 2

# %%
# job_type, work_location
job_type = ""
work_location = ""
for i in range(len(job_type_tag)):
    result = job_type_tag[i].text
    if result.lower() in ["internship", "part time", "full time", "Freelance / Project"]:
        job_type = job_type + " / " + result
    else:
        work_location = work_location + " / " + result 
        
job_type = job_type.strip(" /")
work_location = work_location.strip(" /")
job_type, work_location
# Out:
# ('Internship', 'Remote')

# %%
# experince_years, level, job_skills

skills = job_tags[5].find("div", attrs={"class":"css-y4udm8"}).find_all("div")[-1]
level = skills.find("a", attrs={"class":"css-o171kl"}).text
experince_years = skills.find("span").text
experince_years = experince_years.strip("· ")
job_skills = skills.find_all("a")
job_skills.pop(0)
# print(len(job_skills)) # correct for job 0
skills = ""
for i in range(len(job_skills)):
    skills = skills + job_skills[i].text
skills = skills.strip(" · ")
skills = skills.replace("·", "-")
print(level)
print(experince_years)
print(skills)
# Out:
# Manager
# 10 - 16 Yrs of Exp
# Strategy/Consulting - Artificial IntelligenceComputer Science - Software DevelopmentData Engineer

# %%
job_skills[0].text
# Out:
# ' · Strategy/Consulting'

# %%
pages = soup.find("li", attrs={"class":"css-8neukt"}).text.split(" ")
pages
# Out:
# ['Showing', '1', '-', '15', 'of', '983']

# %%
import requests
from bs4 import BeautifulSoup

link = "https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=0"
res = requests.get(link)
soup = BeautifulSoup(res.text, "html.parser")
pages = soup.find("li", attrs={"class":"css-8neukt"}).text.split(" ")
jobs_in_one_page = int(pages[-3])
total_jobs = int(pages[-1])
result = total_jobs // jobs_in_one_page #
if result == total_jobs / jobs_in_one_page:
    pages = result
else:
    pages = result + 1
    
with open("data_science_jobs.csv", mode='w', encoding="utf-8") as fd:
    fd.write("job_title,company_name,company_location,time,job_type,work_location,level,experince_years,job_skills,url\n") # header
    for page in range(0, pages):
        print(f"scraping data from page {page}")
        res = requests.get(f"https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start={page}")
        soup = BeautifulSoup(res.text, "html.parser")
        job_tags = soup.find_all("div", attrs={"class":"css-1gatmva e1v1l3u10"})
        for i in range(len(job_tags)):
            
            # job_title, url
            job_title_tag = job_tags[i].find("a", attrs={'class':"css-o171kl"})
            job_title = job_title_tag.text.replace('"', "")
            url = job_title_tag.attrs['href']

            # company
            company_name = job_tags[i].find("a", attrs={"class":"css-17s97q8"}).text.strip(" -")

            # location
            company_location = job_tags[i].find("span", attrs={"class":"css-5wys0k"}).text.strip()

            # time
            time = job_tags[i].find("div", attrs={"class":"css-d7j1kk"}).find("div").text # brown and green styles

            # job_type, work_location
            job_type_tag = job_tags[i].find("div", attrs={"class":"css-1lh32fc"}).find_all("a")
            job_type = ""
            work_location = ""
            for j in range(len(job_type_tag)):
                result = job_type_tag[j].text
                if result.lower() in ["internship", "part time", "full time", "freelance / project"]:
                    job_type = job_type + " / " + result
                else:
                    work_location = work_location + " / " + result 

            job_type = job_type.strip(" /")
            work_location = work_location.strip(" /")

            # level, experince_years, skills
            skills = job_tags[i].find("div", attrs={"class":"css-y4udm8"}).find_all("div")[-1]
            level = skills.find("a", attrs={"class":"css-o171kl"}).text
            try:
                experince_years = skills.find("span").text
                experince_years = experince_years.strip("· ")
            except:
                experince_years = "None"
            job_skills = skills.find_all("a")
            job_skills.pop(0)
            # print(len(job_skills)) # correct for job 0
            skills = ""
            for i in range(len(job_skills)):
                skills = skills + job_skills[i].text
            skills = skills.strip(" · ")
            skills = skills.replace("·", "-")
            fd.write(f"\"{job_title}\",\"{company_name}\",\"{company_location}\",\"{time}\",\"{job_type}\",\"{work_location}\",\"{level}\",\"{experince_years}\",\"{skills}\",\"{url}\"\n")
# Out:
# scraping data from page 0
# scraping data from page 1
# scraping data from page 2
# scraping data from page 3
# scraping data from page 4
# scraping data from page 5
# scraping data from page 6
# scraping data from page 7
# scraping data from page 8
# scraping data from page 9
# scraping data from page 10
# scraping data from page 11
# scraping data from page 12
# scraping data from page 13
# scraping data from page 14
# scraping data from page 15
# scraping data from page 16
# scraping data from page 17
# scraping data from page 18
# scraping data from page 19
# scraping data from page 20
# scraping data from page 21
# scraping data from page 22
# scraping data from page 23
# scraping data from page 24
# scraping data from page 25
# scraping data from page 26
# scraping data from page 27
# scraping data from page 28
# scraping data from page 29
# scraping data from page 30
# scraping data from page 31
# scraping data from page 32
# scraping data from page 33
# ...

# %%
import pandas as pd

df = pd.read_csv("data_science_jobs.csv")
df
# Out:
#                                              job_title  \
# 0            AI & Data Science Python Developer Intern
# 1                                         Data Analyst
# 2                                        Data Engineer
# 3                                         Data Analyst
# 4                                         Data Analyst
# ..                                                 ...
# 978  Senior Generative AI Strategist, Generative AI...
# 979                Construction (Civil) - Coop Trainee
# 980  QDI Key Account Manager – Bioinformatics (Midd...
# 981  Information Management Assistant - Internation...
# 982                          Sr. AIML Sales Specialist
#
#                                   company_name             company_location  \
# 0                             Sequel Solutions                 Cairo, Egypt
# 1                                         EGEC           Haram, Giza, Egypt
# ...
